# %% [markdown]
# #**EDA on Data Science** - Data set of  Employee Salaries

# %% [markdown]
# ##**Introduction:**
#  salary is a fixed regular payment, typically paid on a monthly basis but often expressed as an annual sum, made by an employer to an employee, especially a professional or white-collar worker.
#
#  A salary is a form of periodic payment from an employer to an employee, which may be specified in an employment contract. It is contrasted with piece wages, ...
#
# Here the data set contain  details for employees of three years. Employee salaries of different countries with various currency.It also have the information about company means whether it is  large,medium or small in size.It shows the employees details like the employees whose working in this companies are full time employees ,part time employees or contract based employees and also have the information of employee designation(data scientist, data analyst,machine learning scientist etc).
#       It also shows the details of employee belongs to which country, and tells the company location

# %% [markdown]
# ![download (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno

# %% [markdown]
# **Upload** the data set/data file.Depends upon the file the extension occurs(csv for csv files,excel for excel files like that).

# %%
df_salaries=pd.read_csv("/content/ds_salaries.csv")

# %% [markdown]
# **shape attribute**:- Shows the no.of columns/features and row/records of the data set.

# %%
df_salaries.shape
# Out:
# (607, 12)

# %% [markdown]
# **Observations**:- The above data set or file contains 607 records and 12 columns.

# %% [markdown]
# **head():-** the head function displays top 5 records.

# %%
df_salaries.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# **Observations:-** By default the head funciton displays top five records. Depends upon the number what u passed in the paranthesis it displays that much of records.Here u didn't pass any number so it displayed top five records.

# %% [markdown]
# **tail():-** tail function displays last/bottom five records

# %%
df_salaries.tail(9)
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 598         598       2022               MI              FT  Data Scientist
# 599         599       2022               MI              FT  Data Scientist
# 600         600       2022               EN              FT    Data Analyst
# 601         601       2022               EN              FT    Data Analyst
# 602         602       2022               SE              FT   Data Engineer
# 603         603       2022               SE              FT   Data Engineer
# 604         604       2022               SE              FT    Data Analyst
# 605         605       2022               SE              FT    Data Analyst
# 606         606       2022               MI              FT    AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 598  160000             USD         160000                 US           100
# ...

# %% [markdown]
# **Observations:-** By default the tail funciton displays last five records. Depends upon the number what u passed in the paranthesis it displays that much of records.Here i passed nine in paranthesis, so it displayed last nine records from the bottom.

# %% [markdown]
# **columns:-** Displays the list of columns.

# %%
df_salaries.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %% [markdown]
# **Observations:-** The columns attribute displays all column names in object type.

# %% [markdown]
# **info():-**  This function displays whole information about dataset means no.of rows and columns,the type of data is corect or not also shows if any null values occur.

# %%
df_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# **Observations:-**  Here the data set contain 607 records and 12 features. some features are in int data type and some are in object data type.
#
# Int type:
# -> work year,salary,salary_in_usd,remote_ratio
#
# Object type:
# ->experience_level,employment_type,job_title,salary_currency,employee_residence,company_location,company_size.
#
# Here all the data types have correct data, and all features are filled with values means it does'nt occur no null values.

# %% [markdown]
# ##To Find the categorical variables

# %%
df_salaries.select_dtypes(include='object')
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     salary_currency employee_residence company_location company_size
# 0               EUR                 DE               DE            L
# ...

# %%
df_salaries.select_dtypes(include='object').nunique()
# Out:
# experience_level       4
# employment_type        4
# job_title             50
# salary_currency       17
# employee_residence    57
# company_location      50
# company_size           3
# dtype: int64

# %% [markdown]
# **Drop():-** This function drops the selected column.

# %%
df_salaries=df_salaries.drop(['Unnamed: 0'],axis=1)

# %% [markdown]
# **Observations:-** I dropped the **'Unnamed: 0'** bcoz it is not that much used feature in data set.It shows index only that to we didn't do any modifications or mathematical operatoins by using this feature.Now the data set contain 11 columns.

# %%
df_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %% [markdown]
# **duplicated():**-To find out **duplicate records** in the data set

# %%
len(df_salaries[df_salaries.duplicated()])
# Out:
# 42

# %%
df_salaries.duplicated().sum()
# Out:
# 42

# %% [markdown]
# **Observations:-**  In Above both statements gives same result.There are 42 duplicate records in data set.

# %% [markdown]
# **drop_duplicates():-** Removes the duplicated records.

# %%
df_salaries=df_salaries.drop_duplicates(keep='first')

# %% [markdown]
# **Observations:-** Use keep=’first’ to keep the first occurrence of a duplicate,Use keep=’last’ to keep the last occurrence of a duplicate.We removed the 42 duplicated records, now the data set contain 565 rows and 11 columns.

# %%
df_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    int64
#  1   experience_level    565 non-null    object
#  2   employment_type     565 non-null    object
#  3   job_title           565 non-null    object
#  4   salary              565 non-null    int64
#  5   salary_currency     565 non-null    object
#  6   salary_in_usd       565 non-null    int64
#  7   employee_residence  565 non-null    object
#  8   remote_ratio        565 non-null    int64
#  9   company_location    565 non-null    object
#  10  company_size        565 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 53.0+ KB

# %% [markdown]
# **describe():-** It gives statistical information abt all columns.The columns must be data type of continuous.It doesn't shows any values to the categorical variables

# %%
df_salaries.describe().round()
# Out:
#        work_year      salary  salary_in_usd  remote_ratio
# count      565.0       565.0          565.0         565.0
# mean      2021.0    338116.0       110610.0          70.0
# std          1.0   1599879.0        72281.0          41.0
# min       2020.0      4000.0         2859.0           0.0
# 25%       2021.0     67000.0        60757.0          50.0
# 50%       2021.0    110925.0       100000.0         100.0
# 75%       2022.0    165000.0       150000.0         100.0
# max       2022.0  30400000.0       600000.0         100.0

# %% [markdown]
# **Observations:-** Here the work_year has three years values so there is meaning to find out the statistical information on this feature. For Salary the currency is different to one another so we can't find out exact statistical information on this feature. salary_in_usd the min value is 60757 and max is 600000 usd dollars.The mean is 110610 and median is 100000, here mean is greater than median so it clearly tells us it is right skewed.Remote ratio also not correct feature to find the statistical information.

# %% [markdown]
# ## **Show the missing values in graph**

# %%
msno.matrix(df_salaries)
plt.title('Distribution of Missing Values', fontsize = 30, fontstyle='oblique')
# Out:
# Text(0.5, 1.0, 'Distribution of Missing Values')

# %% [markdown]
# **Observations:-** Here the data set have no null values,so that the graph shows the full black bars.If the data set contain any null values it shows white lines in middle of the black bars.

# %% [markdown]
# ## **Univariate analysis**

# %% [markdown]
# ### Now lets work with the next feature work_year

# %% [markdown]
# **value_counts():-** Shows the no.of occurences or no.of items of each category.

# %%
df_salaries['work_year'].value_counts()
# Out:
# 2022    278
# 2021    215
# 2020     72
# Name: work_year, dtype: int64

# %% [markdown]
# **Observations:-** It shows the count of no.of employees in each year. The year 2022 has 318 employees,2021 has 217 employees and 2020 has 72 employees.

# %% [markdown]
# Draw a **pie chart** for work_year

# %%
figure=plt.figure(figsize=(15,7))
df_salaries['work_year'].value_counts().plot(kind='pie',autopct='%3.1f%%',shadow=True)
plt.title(label="Employee percentage of each year", color="red",size=15)
plt.show()

# %% [markdown]
# **Observations:-**  The above pie chart divided into three sectors, each sector shows the  percentage of total employees in each year. The 2020 has 12.7% of employees,2021 has 38.1% of employees and 2022 has 49.2% of employees.

# %% [markdown]
# **Bar Graph for work_year**

# %%
figure= plt.figure(figsize=(15,7))
df_salaries['work_year'].value_counts().plot.bar(color='purple')
plt.title(label="Employees of three years",color='red',size=15)
plt.xlabel(xlabel='Years',size=13,color='red')
plt.xticks(rotation=45)
plt.ylabel(ylabel="No.of employees",color='red',size=13)
plt.show()

# %% [markdown]
# **Observations:-** The above graph shows employees in three years.In 2020 there were 72 employees,2021 has 215 employees and 2022 has 758 employees.Compare to all the 2020 year has least no.of employees.

# %% [markdown]
# **Show value at the top of the bar** -- bar_label() function

# %%
ax=df_salaries['work_year'].value_counts().plot.bar(color='purple')
ax.bar_label(ax.containers[0], label_type='edge')
# Out:
# [Text(0, 0, '278'), Text(0, 0, '215'), Text(0, 0, '72')]

# %% [markdown]
# ###Work with **experience_level**

# %%
df_salaries['experience_level'].value_counts()
# Out:
# SE    243
# MI    208
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %% [markdown]
# **Observations:-**The 'experience_level' has 4 categories. They are SE(senior expert),MI(Management information),EN(Entry level),EX(expert). 243 senior experts,208 MI's,88 Entry level employees,26 Experts.

# %%
df_salaries['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %% [markdown]
# **Pie chart of experience_level using plotly.express library**

# %%
fig = px.pie(df_salaries, values=df_salaries['experience_level'].value_counts(), names=df_salaries['experience_level'].unique(), title='Employees of each category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:-** The pie chart divided into 4 sectors.They are 43.1% of MI's ,36.8% of Senior experts, 15.6% of Entry level ,4.6% of Experts.

# %% [markdown]
# **Bar graph for experience_level using sea born library**

# %%
ax=sns.barplot(df_salaries,x=df_salaries['experience_level'].unique(),y=df_salaries['experience_level'].value_counts())
ax.bar_label(ax.containers[0], label_type='edge')
#fig.tiltle(label="Employees in each category")
plt.show()

# %% [markdown]
# **Observations:-**The above x-axis has categories of employees, y-axis has no.of employees of each category.243 senior experts,208 MI's,88 Entry level employees,26 Experts.

# %% [markdown]
# ###**work with employment_type**

# %%
df_salaries["employment_type"].unique()
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %%
df_salaries["employment_type"].value_counts()
# Out:
# FT    546
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %% [markdown]
# **Observations:-** Here "employment_type" have 4 categories.They are FT- full time employess 546,PT - part time employees 10,CT stands for Career Trainee employees 5,FL-Fine lookin employees 4.

# %% [markdown]
# **Bar chart for employment_type**

# %%
figure=plt.figure(figsize=(15,7))
df_salaries["employment_type"].value_counts().plot.bar(color='green')
plt.xticks(rotation=45,color='blue')
plt.yticks(ticks=np.arange(0,600,50),color='blue')
plt.xlabel(xlabel="Employment type",size=13,color='red')
plt.ylabel(ylabel="No.of employees",size=13,color='red')
plt.title(label=" Employees in employment type",size=16,color='red')
plt.show()

# %% [markdown]
# **Observations:-** Here x-axis shows the Eployment type and y-axis shows the no.of employees.The "employment_type" have 4 categories.They are FT- full time employess 546,PT - part time employees 10,CT stands for Career Trainee employees 5,FL-Fine lookin employees 4.

# %% [markdown]
# **Pie chart for employment_type**

# %%
fig = px.pie(df_salaries, values=df_salaries['employment_type'].value_counts(), names=df_salaries['employment_type'].unique(), title='Types of Employment')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:-** The above pie chart drawn using plotly.express library.Most of the employees(96.6%) were working full time . The remaining employees working as part time,carier trainee etc.

# %% [markdown]
# ### Work with job_title feature

# %%
df_salaries["job_title"].value_counts()
# Out:
# Data Scientist                              130
# Data Engineer                               121
# Data Analyst                                 82
# Machine Learning Engineer                    39
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %% [markdown]
# **Observations:-** Here it shows the count of employees in each category.

# %% [markdown]
# **Bar Graph for Job_Title**

# %%
figure=plt.figure(figsize=(15,7))
df_salaries["job_title"].value_counts().plot.bar(color='purple')
plt.xlabel(xlabel="Job Titles",size=15,color='orange')
plt.ylabel(ylabel="No.of employees in each category",size=13,color='orange')
plt.title(label="Distribution of Employees",size=15,color='orange')
plt.show()

# %% [markdown]
# **Observations:-** The x-axis has Job titles  and y-axis has count of employees in each category. There are Data Scientist   130,
# Data Engineer                               121,
# Data Analyst                                 82,
# Machine Learning Engineer                    39 etc...

# %% [markdown]
# **Bar graph for top 10 values.**

# %%
df_salaries["job_title"].value_counts().iloc[:10].plot.bar(color='purple')  # To show top 10 values, also use nlargest(10) also give the same result.
# Out:
# <Axes: >

# %% [markdown]
# Bar graph for job_title using seaborn

# %%
figure=plt.figure(figsize=(15,7))
top10=df_salaries["job_title"].value_counts().nlargest(10)
sns.barplot(x=top10.index,y=top10)
plt.xticks(rotation=45)
plt.xlabel(xlabel="Job Titles",size=15,color='orange')
plt.ylabel(ylabel="No.of employees in each category",size=13,color='orange')
plt.title(label="Distribution of Employees",size=15,color='orange')
plt.show()

# %% [markdown]
# Bar graph for job_title using plotly.express

# %%
df_salaries['job_title'].value_counts()
# Out:
# Data Scientist                              130
# Data Engineer                               121
# Data Analyst                                 82
# Machine Learning Engineer                    39
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
fig = px.bar(df_salaries,x=df_salaries["job_title"],  color="job_title")   # applying color to graph.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Work with salary currency**

# %%
df_salaries['salary_currency'].value_counts()
# Out:
# USD    359
# EUR     93
# GBP     43
# INR     27
# CAD     18
# JPY      3
# PLN      3
# TRY      3
# CNY      2
# MXN      2
# HUF      2
# DKK      2
# SGD      2
# BRL      2
# AUD      2
# CLP      1
# CHF      1
# Name: salary_currency, dtype: int64

# %% [markdown]
# **Pie chart for salary_currency**

# %%
fig = px.pie(df_salaries, values=df_salaries['salary_currency'].value_counts(), names=df_salaries['salary_currency'].unique(), title='Currency of various countries')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:-** The above pie chart most of the employees took the salary in euro's(63.5%) currency.The remaining employees took the salary in different currencies.

# %% [markdown]
# **Bar chart for salary_currency**

# %%
plt.figure(figsize = (16,8))
sns.countplot(data=df_salaries, x = 'salary_currency')
# Out:
# <Axes: xlabel='salary_currency', ylabel='count'>

# %%
figure=plt.figure(figsize=(15,7))
ax=df_salaries['salary_currency'].value_counts().nlargest(6).plot.bar(color='orange')
ax.bar_label(ax.containers[0], label_type='edge')
plt.xlabel(xlabel="salary_currency",size=13,color='red')
plt.ylabel(ylabel='Frequency of currency',size=13,color='red')
plt.title(label="Currency of various countries",size=15,color='red')
plt.show()

# %% [markdown]
# **Observations:** Above bar graph x-axis has salary_currency and y-axis has frequency of currency. Here 359 employees took the salaries in USD dollars. 93 employees took euro's. The remaining took different currencies.

# %% [markdown]
# ### **Work with salary_in_usd**

# %%
df_salaries['salary_in_usd'].describe()
# Out:
# count       565.000000
# mean     110610.343363
# std       72280.702792
# min        2859.000000
# 25%       60757.000000
# 50%      100000.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# #### Histogram for salary_in_usd

# %%
figure=plt.figure(figsize=(15,7))
ax=df_salaries['salary_in_usd'].plot.hist(color='green')
ax.bar_label(ax.containers[0], label_type='edge')
plt.xticks(ticks=np.arange(0,600000,50000),rotation=45)
plt.xlabel(xlabel='Salary_in_usd',size=14,color='red')
plt.ylabel(ylabel='Frequency of employees',size=14,color='red')
plt.title(label="Frequency of employees salary",size=15,color='red')
plt.show()

# %% [markdown]
# **Observations:-** The x-axis has salary_in_usd and y-axis has Frequency of employees. Here 215 employees got the salary between 50,000 to one lakh,146 employees got salary less than 50,000 , 130 employees got salary between one lakh to 1.5 lakh , remaining employees got various packages and only one employee got above 5.5lakhs.

# %% [markdown]
# #### displot for 'salary_in_usd' using sea born

# %%
figure=plt.figure(figsize=(16,8))
sns.displot(df_salaries['salary_in_usd'],kde=True)

# %% [markdown]
# **Scatter plot for salary_in_usd**

# %%
figure = plt.figure(figsize=(15,7))
plt.scatter(df_salaries['salary_in_usd'],df_salaries.index,color="purple")
plt.xticks(ticks=np.arange(0,600000,50000),rotation=45)
plt.xlabel(xlabel='Salary_in_usd',size=14,color='red')
plt.ylabel(ylabel='Frequency of employees',size=14,color='red')
plt.title(label="Frequency of employees salary",size=15,color='red')
plt.show()

# %% [markdown]
# **Strip plot for salary_in_usd using seaborn**

# %%
sns.set(rc={'figure.figsize':(10,7)})  #Setting title,figure_size,font,labels in seaborn
sns.set(font_scale=1.5)
sns.stripplot(x=df_salaries['salary_in_usd'])
#plt.xticks(ticks=np.arange(0,600000,50000),rotation=45)
plt.xlabel(xlabel='Salary_in_usd',size=14,color='red')
plt.ylabel(ylabel='Frequency of employees',size=14,color='red')
plt.title(label="Frequency of employees salary",size=15,color='red')
plt.show()

# %% [markdown]
# ### **Work with company size**

# %%
df_salaries['company_size'].value_counts()
# Out:
# M    290
# L    193
# S     82
# Name: company_size, dtype: int64

# %% [markdown]
# **Funnel Graph for company size**

# %%
fig = px.funnel(df_salaries, x=df_salaries['company_size'].value_counts(), y=df_salaries['company_size'].unique())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:-** The above funnel graph drawn using plotly.express library. Here the x-axis has count of company size and y-axis shows the categories in company(large,midium,small). Most of the companies are large companies(290).

# %% [markdown]
# ### **Work with employee_residence**

# %%
df_salaries['employee_residence'].value_counts().nlargest(10)
# Out:
# US    295
# GB     43
# IN     30
# CA     27
# DE     24
# FR     18
# ES     15
# GR     12
# JP      7
# PT      6
# Name: employee_residence, dtype: int64

# %% [markdown]
# **bar graph for employee_residence**

# %%
figure=plt.figure(figsize=(15,7))
ax=df_salaries['employee_residence'].value_counts().nlargest(10).plot.bar(color='purple')
ax.bar_label(ax.containers[0], label_type='edge')
plt.xlabel('Employee Residency',size=14,color='red')
plt.ylabel('Frequency of employees',size=14,color='red')
plt.title("Employees of each country",size=15,color='red')
plt.show()

# %% [markdown]
# **Observations:-** Here the x-axis shows the countreis and y-axis shows frequency of employees.Most of the employees are from US(295),GB(43) so on.Above graph displays only top 10 countries bcoz remaining countries have 1 or 2 employees.

# %% [markdown]
# ### Work with company_location

# %%
df_salaries['company_location'].value_counts().nlargest(10)
# Out:
# US    318
# GB     46
# CA     28
# DE     27
# IN     24
# FR     15
# ES     14
# GR     10
# JP      6
# NL      4
# Name: company_location, dtype: int64

# %%
ax=df_salaries['company_location'].value_counts().nlargest(10).plot.bar(color='pink')
ax.bar_label(ax.containers[0], label_type='edge')
plt.xlabel('company_location',size=14,color='red')
plt.ylabel('Frequency of companies',size=14,color='red')
plt.title("Companies of each country",size=15,color='red')
plt.show()

# %% [markdown]
# **Observations:-** Here the x-axis shows the countreis and y-axis shows frequency of employees.The Us contains 318 companies where as GB-46,CA-28 and so on.Above graph displays only top 10 countries bcoz remaining countries have 1 or 2 companies.

# %% [markdown]
# ## **Bi-Variate Analysis**

# %% [markdown]
# ### **Work with the features work_year and company_size**

# %% [markdown]
#  Count plot using sea born

# %%
sns.set(rc={'figure.figsize':(10,7)})  #Setting title,figure_size,font,labels in seaborn
sns.set(font_scale=1.5)
sns.countplot(x=df_salaries['work_year'],hue='company_size',data=df_salaries)
plt.title("Companies Growth in Three Years",size=15,color='red')
# Out:
# Text(0.5, 1.0, 'Companies Growth in Three Years')

# %% [markdown]
# **Observations:-**  In above graph x-axis has three years and y-axis has count of companies. In year 2020 large companies are more compared to middle companies. 2021 large companies grown fastly compared to small and middle companies.2022 Middle companies grown rapidly where as small and large companies growth fell down.

# %% [markdown]
# ### Box plots for work_year and salary_in_usd

# %%
df_salaries.groupby(by=["work_year"]).agg({'salary_in_usd':'mean'})
# Out:
#            salary_in_usd
# work_year
# 2020        95813.000000
# 2021        99430.413953
# 2022       123089.097122

# %%
plt.figure(figsize=(15,7))
plt.title("Box plots for salaries of Three Years ")
sns.boxplot(x='work_year', y=  'salary_in_usd', palette='rainbow', data=df_salaries)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observations:-** Here x-axis shows the three years and y-axis has salary in usd.The box plot shows mean.median and outliers of salaries for three years.Three years have some upper outliers.

# %% [markdown]
# ### Bar plot for salary_in_usd and company size using sea born

# %%
plt.figure(figsize = (16,8))
sns.barplot(x=df_salaries['company_size'], y= df_salaries['salary_in_usd'],data=df_salaries)
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
plt.title('Company size Vs Salary in USD')
# Out:
# Text(0.5, 1.0, 'Company size Vs Salary in USD')

# %% [markdown]
# **Observations:-** Here above graph x-axis shows company size and y-axis shows salary in usd. The large company and midium company pay much amount to the employees.

# %% [markdown]
# ##  **Multivariate Analysis**

# %% [markdown]
# 1. Which job title earns highest salary ?
# 2. What is the average salary for each experience level ?
# 3. What is the average salary for company size Large, Small and Medium ?
# 4. Does people working full time earns more than contract base employees ?
# 5. Is salary less for employee woking remotely than who comes to office ?
# 6. Which country pays more to the employees ?
# 7. What is the highest earning job in highest paying countries ?
# 8. What is the highest earning job titles working at expert level ?
# 9. What is the highest earning job titles working at senioir level ?
# 10. Has salary of data science job roles increased over the passing years ?
# 11. What is the trend of salary paid by medium size company over the passing years ?
# 12. What is the trend of salary paid by large size company over the passing years ?
# 13. What is the trend of salary paid by small size company over the passing years ?

# %% [markdown]
# ### 1) Which job title earns highest salary?

# %%
df_salaries['job_title'].head(7)
# Out:
# 0                Data Scientist
# 1    Machine Learning Scientist
# 2             Big Data Engineer
# 3          Product Data Analyst
# 4     Machine Learning Engineer
# 5                  Data Analyst
# 6           Lead Data Scientist
# Name: job_title, dtype: object

# %%
df_salaries.groupby(by='job_title').agg({'salary_in_usd':'mean'}).nlargest(10,'salary_in_usd')
# Out:
#                           salary_in_usd
# job_title
# Data Analytics Lead       405000.000000
# Principal Data Engineer   328333.333333
# Financial Data Analyst    275000.000000
# Principal Data Scientist  215242.428571
# Director of Data Science  195074.000000
# Data Architect            177873.909091
# Applied Data Scientist    175655.000000
# Analytics Engineer        175000.000000
# Data Specialist           165000.000000
# Head of Data              160162.600000

# %%
figure=plt.figure(figsize=(15,7))
fig = px.bar(df_salaries.groupby(by='job_title').agg({'salary_in_usd':'mean'}).nlargest(10,'salary_in_usd'),title='Highest salary for job_title')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observartions:** Here the drawn graph shows relation of two features those are job_title and salary_in_usd. x-axis has job titles and y-axis has frequency of salaries. The role **Data Analytics Lead** got highest salaries i.e 405k dollars. Above graph shows only ten roles who got highest salaries.

# %%
fig = px.bar( df_salaries.groupby(by='job_title').agg({'salary_in_usd':'mean'}),title='Salaries of different jobs')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2) What is the average salary for each experience level?

# %%
df_salaries.groupby(by='experience_level').agg({'salary_in_usd':'mean'})
# Out:
#                   salary_in_usd
# experience_level
# EN                 61643.318182
# EX                199392.038462
# MI                 87792.995192
# SE                138374.880658

# %% [markdown]
# **Average salary for each experience level**

# %%
fig = px.bar( df_salaries.groupby(by='experience_level').agg({'salary_in_usd':'mean'}),title='Average salary for each experience level')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:-** Here the above graph x-axis shows the Experience_levels and y-axis shows the average salary of each level. The mean values of EN is 61.643k,EI is 199.392k,MI is 87.793k,SE is 138.374k. Compared to all levels the EX level has highest mean value.

# %%
figure=plt.figure(figsize=(15,7))
df_salaries.groupby(by=['experience_level'])['salary_in_usd'].mean().nlargest(5).plot(kind='pie',autopct='%3.2f%%',shadow=True, wedgeprops=dict(width=0.15))
plt.title('Average salary for each experience level',size=16,color='purple')
# Out:
# Text(0.5, 1.0, 'Average salary for each experience level')

# %% [markdown]
# **Observations:** The above pie chart shows the details those who got highest salary in percentage. EX(experts )got highest salary percentage 40.93. etc

# %% [markdown]
# ### 3) What is the average salary for company size Large, Small and Medium ?

# %%
df_salaries.groupby(by='company_size').agg({'salary_in_usd':'mean'})
# Out:
#               salary_in_usd
# company_size
# L             118213.880829
# M             114807.079310
# S              77872.097561

# %%
fig = px.bar( df_salaries.groupby(by='company_size').agg({'salary_in_usd':'mean'}),title='Average salaries of diffrerent companies')
fig.show()

# %% [markdown]
# **Observations:-** In above graph x-axis is companies size and y-axis is salay in usd. There is a slight difference in average salaries of large company and medium company.

# %% [markdown]
# ### 4) Does people working full time earns more than contract base employees ?

# %%
ft_salaries=df_salaries[df_salaries["employment_type"]=='FT']

# %%
ft_salaries
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
ct_salaries=df_salaries[df_salaries["employment_type"]=='CT']

# %%
ct_salaries
# Out:
#      work_year experience_level employment_type  \
# 28        2020               EN              CT
# 78        2021               MI              CT
# 225       2021               EX              CT
# 283       2021               SE              CT
# 489       2022               EN              CT
#
#                               job_title  salary salary_currency  \
# 28                Business Data Analyst  100000             USD
# 78                          ML Engineer  270000             USD
# 225            Principal Data Scientist  416000             USD
# 283                Staff Data Scientist  105000             USD
# 489  Applied Machine Learning Scientist   29000             EUR
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 28          100000                 US           100               US
# 78          270000                 US           100               US
# 225         416000                 US           100               US
# ...

# %%
ft_salaries['salary_in_usd'].mean()
# Out:
# 111811.83882783883

# %%
ct_salaries['salary_in_usd'].mean()
# Out:
# 184575.0

# %%
figure=plt.figure(figsize=(15,7))
df_salaries.groupby(by=['employment_type'])['salary_in_usd'].mean().plot.bar(color='pink')
plt.title(' people working full time earns more than contract base employees',color='brown',size=16)
plt.xlabel(xlabel='Employment_Type',size=14,color='orange')
# Out:
# <Axes: xlabel='employment_type'>

# %% [markdown]
# **Observations:** x-axis has employment_type and y-axis has salary_in_usd. Here the CT(contract based ) employees are 5 members but they got highest salaries where as the FT(full time) employees are 546 but they got less salaries compare to CT employees.

# %% [markdown]
# ### 5) Is salary less for employee woking remotely than who comes to office ?

# %%
df_salaries['remote_ratio'].value_counts()
# Out:
# 100    346
# 0      121
# 50      98
# Name: remote_ratio, dtype: int64

# %%
df_salaries.groupby(by=['remote_ratio'])['salary_in_usd'].mean().sort_values()
# Out:
# remote_ratio
# 50      80823.030303
# 0      106354.622047
# 100    122457.454068
# Name: salary_in_usd, dtype: float64

# %%
df_salaries.groupby(by=['remote_ratio'])['salary_in_usd'].mean().sort_values().plot.bar(color='purple')
# Out:
# <Axes: xlabel='remote_ratio'>

# %% [markdown]
# ### 6. Which country pays more to the employees ?

# %%
df_salaries.groupby(by=['company_location'])['salary_in_usd'].mean().sort_values()
# Out:
# company_location
# VN      4000.000000
# IR      4000.000000
# KE      9272.000000
# PK     13333.333333
# UA     13400.000000
# MD     18000.000000
# AS     18053.000000
# BR     18602.666667
# HN     20000.000000
# TR     20096.666667
# CO     21844.000000
# MT     28369.000000
# IN     28581.750000
# NG     30000.000000
# MX     32123.333333
# EE     32974.000000
# HU     35735.000000
# IT     36366.500000
# MY     40000.000000
# CL     40038.000000
# LU     43942.666667
# HR     45618.000000
# PT     47793.750000
# CZ     50937.000000
# GR     52026.700000
# ES     53060.142857
# DK     54386.333333
# NL     54945.750000
# RO     60000.000000
# SI     63831.000000
# FR     63970.666667
# CH     64114.000000
# PL     66082.500000
# IE     71444.000000
# CN     71665.500000
# AT     72920.750000
# DE     81559.555556
# GB     81649.500000
# BE     85699.000000
# SG     89294.000000
# AE    100000.000000
# IQ    100000.000000
# DZ    100000.000000
# CA    100121.857143
# ...

# %%
figure=plt.figure(figsize=(15,7))
df_salaries.groupby(by=['company_location'])['salary_in_usd'].mean().nlargest(9).plot(kind='pie',autopct='%3.2f%%')
# Out:
# <Axes: ylabel='salary_in_usd'>

# %%
figure=plt.figure(figsize=(15,7))
df_salaries.groupby(by=['company_location'])['salary_in_usd'].mean().nlargest(9).plot.bar(color='green')
plt.xlabel(xlabel='Countries names',size=14,color='red')
plt.ylabel(ylabel='Frequency of salaries in usd',size=14,color='red')
plt.title(label="Salaries of each country",size=16,color='red')
plt.show()

# %% [markdown]
# **Observations:-** Here x-axis has country names and y-axis has frequency of salary.The graph clearly tell that country RU(Russia) pays much amount compared to other countries but here we cann't say excatly that may RU have more employees or it pays high amount to the employees.

# %% [markdown]
# ### 7) What is the highest earning job in highest paying countries ?

# %% [markdown]
# **Here we have to work with multivariants- salary_in_usd,company_location,job_title**

# %%
df_salaries.groupby(by=['company_location'])['salary_in_usd'].mean().nlargest(1)
# Out:
# company_location
# RU    157500.0
# Name: salary_in_usd, dtype: float64

# %%
Ru_salaries=df_salaries[df_salaries['company_location']=='RU']

# %%
Ru_salaries
# Out:
#      work_year experience_level employment_type             job_title  salary  \
# 160       2021               EX              FT          Head of Data  230000
# 161       2021               EX              FT  Head of Data Science   85000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 160             USD         230000                 RU            50
# 161             USD          85000                 RU             0
#
#     company_location company_size
# 160               RU            L
# 161               RU            M

# %%
hej= Ru_salaries.groupby(by=['job_title'])['salary_in_usd'].mean()
hej
# Out:
# job_title
# Head of Data            230000.0
# Head of Data Science     85000.0
# Name: salary_in_usd, dtype: float64

# %%
fig =px.bar(Ru_salaries, x ='job_title', y=hej,title='Highest earning jobs in highset paying countries')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observations:**  x-axis has job_title, y-axis has frequency of salary. Already we know that country RU paying highest salary,in that the 'Head of Data' employees getting highest salary.

# %% [markdown]
# ### 8) What is the highest earning job titles working at expert level ?

# %% [markdown]
# **The columns which have to use - salary_in_usd,job_title,experience_level**

# %%
df_salaries['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
el_salaries=df_salaries[df_salaries['experience_level']=='EX']

# %%
el_salaries
# Out:
#      work_year experience_level employment_type                 job_title  \
# 25        2020               EX              FT  Director of Data Science
# 41        2020               EX              FT  Data Engineering Manager
# 73        2021               EX              FT           BI Data Analyst
# 74        2021               EX              FT              Head of Data
# 84        2021               EX              FT  Director of Data Science
# 160       2021               EX              FT              Head of Data
# 161       2021               EX              FT      Head of Data Science
# 164       2021               EX              FT  Director of Data Science
# 167       2021               EX              FT  Director of Data Science
# 187       2021               EX              FT   Data Science Consultant
# 225       2021               EX              CT  Principal Data Scientist
# 252       2021               EX              FT   Principal Data Engineer
# ...

# %%
el_salaries.groupby(by=['job_title'])['salary_in_usd'].mean().nlargest(5)
# Out:
# job_title
# Principal Data Engineer     600000.000000
# Principal Data Scientist    416000.000000
# Data Engineer               245500.000000
# Head of Data                232500.000000
# Director of Data Science    199586.333333
# Name: salary_in_usd, dtype: float64

# %%
figure=plt.figure(figsize=(15,7))
el_salaries.groupby(by=['job_title'])['salary_in_usd'].mean().nlargest(5).plot(kind='pie',autopct='%3.2f%%',shadow=True, wedgeprops=dict(width=0.15))
# Out:
# <Axes: ylabel='salary_in_usd'>

# %% [markdown]
# **Observations:-**  Here the pie chart shows the relation of three features those are job_title,salary_in_usd,experience_level.The 'principal Data Engineer' of 'EX'(Expert level) in experience level got highest salaries.

# %% [markdown]
# ### 9) What is the highest earning job titles working at senioir level ?

# %%
se_salaries=df_salaries[df_salaries['experience_level']=='SE']

# %%
se_salaries
# Out:
#      work_year experience_level employment_type                   job_title  \
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 4         2020               SE              FT   Machine Learning Engineer
# 6         2020               SE              FT         Lead Data Scientist
# 9         2020               SE              FT          Lead Data Engineer
# ..         ...              ...             ...                         ...
# 595       2022               SE              FT      Data Analytics Manager
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
#
# ...

# %%
se_salaries.groupby(by=['job_title'])['salary_in_usd'].mean().nlargest(9)
# Out:
# job_title
# Data Analytics Lead                         405000.000000
# Applied Data Scientist                      278500.000000
# ML Engineer                                 256000.000000
# Machine Learning Scientist                  201666.666667
# Analytics Engineer                          195000.000000
# Machine Learning Infrastructure Engineer    195000.000000
# Principal Data Engineer                     192500.000000
# Principal Data Scientist                    187939.400000
# Data Architect                              182076.625000
# Name: salary_in_usd, dtype: float64

# %%
figure=plt.figure(figsize=(15,7))
ax=se_salaries.groupby(by=['job_title'])['salary_in_usd'].mean().nlargest(5).plot.bar(color='orange')
ax.bar_label(ax.containers[0], label_type='edge')
plt.title("Highest earning job at senioir level",size=16,color='brown')
plt.xlabel("Job Titles",size=16,color='brown')
plt.ylabel("Salary_in_usd",size=16,color='brown')
plt.show()

# %%
se_salaries.groupby(by=['job_title'])['salary_in_usd'].mean().nlargest(9).plot(kind='pie',autopct='%3.2f%%',shadow=True)
# Out:
# <Axes: ylabel='salary_in_usd'>

# %% [markdown]
# **Observations:-**  Here the pie chart shows the relation of three features those are job_title,salary_in_usd,experience_level.The 'Data Analytics Lead' of 'SE'(Senior level) in experience level got highest salaries.

# %% [markdown]
# ### 10) Has salary of data science job roles increased over the passing years ?

# %% [markdown]
# **work_year and salary_in_usd ,select only data science jobs from job_titile**

# %%
df_salaries['job_title'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
df_salaries['job_title'] = df_salaries['job_title'].replace(['Lead Data Scientist','Data Science Manager','Data Science Consultant','Head of Data Science','Applied Data Scientist'],'Data Scientist')

# %% [markdown]
# ### Function to segment job titles

# %%
def segment_job_title(job_title):
  if 'Data Scientist' in job_title or 'Lead Data Scientist' in job_title or 'Applied Data Scientist' in job_title or 'Data Science Consultant' in job_title:
    return 'Data Scientist'
  elif 'Director of Data Science' in job_title or 'Principal Data Scientist' in job_title or 'Head of Data' in job_title or 'Head of Data Science' in job_title:
    return 'Data Scientist'
  elif 'Data Engineer' in job_title or 'Director of Data Science' in job_title:
    return 'Data Engineer'
  elif 'Machine Learning Scientist' in job_title or 'Machine Learning Manager' in job_title or 'Machine Learning Infrastructure Engineer' in job_title or 'Machine Learning Developer' in job_title:
    return 'Machine Learning Engineer'
  elif 'Lead Machine Learning Engineer'in job_title or 'Machine Learning Developer' in job_title or 'ML Engineer' in job_title:
    return 'Machine Learning Engineer'
  elif 'BI Data Analyst' in job_title or 'Business Data Analyst' in job_title or 'Data Analyst' in job_title or 'Analytics Engineer' in job_title or 'Data Analytics Engineer' in job_title or 'Financial Data Analyst' in job_title or 'Marketing Data Analyst' in job_title:
    return 'Data Analyst'
  elif 'Financial Data Analyst' in job_title:
    return 'Data Analyst'
  elif 'NLP Engineer' in job_title:
    return 'NLP Engineer'
  elif 'Computer Vision Software Engineer' in job_title or '3D Computer Vision Researcher' in job_title:
    return 'Computer Vision'
  elif 'AI Scientist' in job_title:
    return 'AI'
  else:
    return 'Others'

# Apply the segmentation function to each job title
df_salaries['Segment_Job'] = df_salaries['job_title'].apply(segment_job_title)

# %%
df_salaries['Segment_Job'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Engineer', 'Data Engineer',
#        'Data Analyst', 'Others', 'AI', 'Computer Vision', 'NLP Engineer'],
#       dtype=object)

# %%
dscience_salaries=df_salaries[df_salaries['Segment_Job']=='Data Scientist']

# %%
dscience_salaries

# %%
datascience=dscience_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'})

# %%
datascience
# Out:
#            salary_in_usd
# work_year
# 2020        99716.629630
# 2021        96745.838235
# 2022       138342.608108

# %%
dscience_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}).plot.bar(color='purple')
# Out:
# <Axes: xlabel='work_year'>

# %% [markdown]
# **Observations:-**  In the above graph x-axis shows years and y-axis shows salary.The salary of data scientist increased from 2020 to 2022.

# %% [markdown]
# ### 11) What is the trend of salary paid by medium size company over the passing years ?

# %% [markdown]
# **The columns we have to use - salary_in_usd,company_size,work_year**

# %%
mcs_salaries=df_salaries[df_salaries['company_size']=='M']   # get details of medium size company

# %%
mcs_salaries
# Out:
#      work_year experience_level employment_type                  job_title  \
# 2         2020               SE              FT          Big Data Engineer
# 12        2020               EN              FT             Data Scientist
# 18        2020               EN              FT    Data Science Consultant
# 19        2020               MI              FT         Lead Data Engineer
# 20        2020               MI              FT  Machine Learning Engineer
# ..         ...              ...             ...                        ...
# 601       2022               EN              FT               Data Analyst
# 602       2022               SE              FT              Data Engineer
# 603       2022               SE              FT              Data Engineer
# 604       2022               SE              FT               Data Analyst
# 605       2022               SE              FT               Data Analyst
#
# ...

# %%
mcs_year=mcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'})   # Find out the average of three years

# %%
mcs_year
# Out:
#            salary_in_usd
# work_year
# 2020       115467.500000
# 2021        74154.792453
# 2022       124427.372197

# %%
mcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'})    #  Find out the average of three years
# Out:
#            salary_in_usd
# work_year
# 2020       115467.500000
# 2021        74154.792453
# 2022       124427.372197

# %%
figure=plt.figure(figsize=(15,7))
mcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}).plot.bar(color='pink')
plt.yticks(ticks=np.arange(0,130000,10000))
plt.xlabel('Year',color='red',size=14)
plt.ylabel('Salary',color='red',size=14)
plt.title('Trend of salary paid by medium size company over the passing years',color='red',size=14)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(mcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}))
ax.set_xticks([2020,2021,2022])
ax.set_xlabel('Year',color='red',size=14)
ax.set_ylabel('Salary',color='red',size=14)
ax.set_title('Trend of salary paid by medium size company over the passing years',color='red',size=14)
plt.show()

# %% [markdown]
# **Observations:**  In the above graph x-axis shows years and y-axis shows salary.The trend of salaries paid by medium company was good at 2020 but its fell down in 2021 year  again it raised in 2022.

# %% [markdown]
# ### 12) What is the trend of salary paid by large size company over the passing years ?

# %%
lcs_salaries=df_salaries[df_salaries['company_size']=='L']

# %%
lcs_salaries

# %%
lcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'})
# Out:
#            salary_in_usd
# work_year
# 2020       106303.848485
# 2021       117772.581197
# 2022       128554.883721

# %%
lcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}).plot.bar(color='brown')
plt.yticks(ticks=np.arange(0,130000,10000))
plt.xlabel('Year',color='red',size=14)
plt.ylabel('Salary',color='red',size=14)
plt.title('Trend of salary paid by large size company over the passing years',color='purple',size=14)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(lcs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}))
ax.set_xticks([2020,2021,2022])
ax.set_xlabel('Year',color='red',size=14)
ax.set_ylabel('Salary',color='red',size=14)
ax.set_title('Trend of salary paid by large size company over the passing years',color='red',size=14)
plt.show()

# %% [markdown]
# **Observations:**  In the above graph x-axis shows years and y-axis shows salary.The trend of salaries paid by large company was increased year by year means  large companies were grown rapidly.

# %% [markdown]
# ### 13) What is the trend of salary paid by small size company over the passing years ?

# %%
scs_salaries=df_salaries[df_salaries['company_size']=='S']

# %%
scs_salaries
# Out:
#      work_year experience_level employment_type  \
# 1         2020               SE              FT
# 3         2020               MI              FT
# 6         2020               SE              FT
# 9         2020               SE              FT
# 10        2020               EN              FT
# ..         ...              ...             ...
# 510       2022               EN              FT
# 512       2022               EN              FT
# 513       2022               SE              FT
# 515       2022               MI              FT
# 522       2022               MI              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 1           Machine Learning Scientist  260000             USD         260000
# 3                 Product Data Analyst   20000             USD          20000
# 6                  Lead Data Scientist  190000             USD         190000
# ...

# %%
scs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'})
# Out:
#            salary_in_usd
# work_year
# 2020        70958.560000
# 2021        81509.844444
# 2022        78633.750000

# %%
figure=plt.figure(figsize=(15,7))
scs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}).plot.bar(color='green')
plt.xlabel('Year',color='red',size=14)
plt.ylabel('Salary',color='red',size=14)
plt.title('Trend of salary paid by small size company over the passing years',color='red',size=14)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(scs_salaries.groupby(by=['work_year']).agg({'salary_in_usd':'mean'}))
ax.set_xticks([2020,2021,2022])
ax.set_xlabel('Year',color='red',size=14)
ax.set_ylabel('Salary',color='red',size=14)
ax.set_title('Trend of salary paid by medium size company over the passing years',color='red',size=14)
plt.show()

# %% [markdown]
# **Observations:**  In the above graph x-axis shows years and y-axis shows salary.The trend of salaries paid by small company was increased from 2020 to 2021 but it decreased in 2022.

# %% [markdown]
# ## **Work on Categorical variables**

# %% [markdown]
# **To find only categorical variables**

# %%
df_salaries.select_dtypes(include='object').nunique()
# Out:
# experience_level       4
# employment_type        4
# job_title             50
# salary_currency       17
# employee_residence    57
# company_location      50
# company_size           3
# dtype: int64

# %% [markdown]
# **Observations:-**  Here the select_dtypes selects the columns which are object type.

# %%
df_salaries.select_dtypes(include='object')
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     salary_currency employee_residence company_location company_size
# 0               EUR                 DE               DE            L
# ...

# %% [markdown]
# ####**To Drop the salary and salary_currency columns**

# %%
df_salaries=df_salaries.drop(columns=['salary','salary_currency'])

# %%
df_salaries.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# **Observations:**  Here I deleted the unnecessary columns which are not in use.

# %% [markdown]
# ###**Assign multiple job titles into single job_titile**

# %%
df_salaries['job_title'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
def segment_job_title(job_title):
  if job_title in ['Data Scientist','Lead Data Scientist','Data Science Consultant','Director of Data Science','Principal Data Scientist','Machine Learning Scientist']:
    return 'Data Scientist'
  elif job_title in ['Data Science Manager','Applied Data Scientist','Data Science Engineer','Head of Data Science','Staff Data Scientist','AI Scientist']:
    return 'Data Scientist'
  elif job_title in ['Product Data Analyst','Data Analyst','Business Data Analyst','Lead Data Analyst','BI Data Analyst','Data Analytics Manager']:
    return 'Data Analyst'
  elif  job_title in ['Finance Data Analyst', 'Principal Data Analyst','Data Analytics Lead']:
    return 'Data Analyst'
  elif job_title in ['Big Data Engineer','Machine Learning Engineer','Lead Data Engineer', 'Data Engineer','Machine Learning Infrastructure Engineer']:
    return 'Data Engineer'
  elif  job_title in ['ML Engineer','Computer Vision Engineer','Data Science Engineer','Principal Data Engineer','NLP Engineer','Lead Machine Learning Engineer']:
    return 'Data Engineer'
  elif job_title in ['Cloud Data Engineer',]:
    return 'Data Engineer'
  elif  job_title in ['Machine Learning Manager','Data Engineering Manager','Machine Learning Developer']:
    return
  else:
     return 'others'

 # Apply the segmentation function to each job title
df_salaries['Segment_Job'] = df_salaries['job_title'].apply(segment_job_title)

# %%
df_salaries['Segment_Job']
# Out:
# 0      Data Scientist
# 1      Data Scientist
# 2       Data Engineer
# 3        Data Analyst
# 4       Data Engineer
#             ...
# 602     Data Engineer
# 603     Data Engineer
# 604      Data Analyst
# 605      Data Analyst
# 606    Data Scientist
# Name: Segment_Job, Length: 607, dtype: object
